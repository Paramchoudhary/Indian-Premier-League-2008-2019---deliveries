# %%
# Importing the libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Knowing the dataset

# %%
file_path="deliveries.csv"
df=pd.read_csv(file_path)

# %%
ball_df = pd.read_csv("deliveries.csv")

# %%
ball_df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
numberofrows_1, numberofcolumns_1 = ball_df.shape
print('There are {} rows and {} columns'.format(numberofrows_1, numberofcolumns_1)+' in our deliveries Dataset.')
# Out:
# There are 179078 rows and 21 columns in our deliveries Dataset.

# %%
ball_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
ball_df.dtypes
# Out:
# match_id             int64
# inning               int64
# batting_team        object
# bowling_team        object
# over                 int64
# ball                 int64
# batsman             object
# non_striker         object
# bowler              object
# is_super_over        int64
# wide_runs            int64
# bye_runs             int64
# legbye_runs          int64
# noball_runs          int64
# penalty_runs         int64
# batsman_runs         int64
# extra_runs           int64
# total_runs           int64
# player_dismissed    object
# dismissal_kind      object
# fielder             object
# dtype: object

# %%
ball_df.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
print('There are {} rows and {} columns'.format(ball_df.shape[0], ball_df.shape[1])+' in our modified smoke Dataset.')
# Out:
# There are 179078 rows and 21 columns in our modified smoke Dataset.

# %%
ball_df.nunique().to_frame(name = 'Unique Values')
# Out:
#                   Unique Values
# match_id                    756
# inning                        5
# batting_team                 15
# bowling_team                 15
# over                         20
# ball                          9
# batsman                     516
# non_striker                 511
# bowler                      405
# is_super_over                 2
# wide_runs                     6
# bye_runs                      5
# legbye_runs                   6
# noball_runs                   5
# penalty_runs                  2
# batsman_runs                  8
# extra_runs                    7
# total_runs                   10
# player_dismissed            487
# dismissal_kind                9
# fielder                     499

# %% [markdown]
# # What Analysis can be done in this?

# %%
ball_df['ball'].value_counts().to_frame(name = 'Count').head()
# Out:
#    Count
# 1  29047
# 2  28963
# 3  28878
# 4  28812
# 5  28720

# %%
# Generate count statistics of duplicate entries

if (len(ball_df[smoke_df.duplicated()]) > 0):
    print('No. of duplicated entries: ', len(ball_df[ball_df.duplicated()]))
    print(ball_df[smoke_df.duplicated(keep = False)].sort_values(by = list(ball_df.columns)).head())
else:
    print('No duplicated entries found.')
# Out:
# No. of duplicated entries:  23
#         match_id  inning      batting_team                 bowling_team  over  \
# 52169        221       1    Mumbai Indians             Delhi Daredevils     4
# 52178        221       1    Mumbai Indians             Delhi Daredevils     4
# 162803      7946       1  Rajasthan Royals  Royal Challengers Bangalore     4
# 162805      7946       1  Rajasthan Royals  Royal Challengers Bangalore     4
# 162804      7946       1  Rajasthan Royals  Royal Challengers Bangalore     4
#
#         ball       batsman  non_striker      bowler  is_super_over  ...  \
# 52169      1  SR Tendulkar      C Madan  PJ Sangwan              0  ...
# 52178      1  SR Tendulkar      C Madan  PJ Sangwan              0  ...
# 162803     4     AM Rahane  RA Tripathi    UT Yadav              0  ...
# 162805     4     AM Rahane  RA Tripathi    UT Yadav              0  ...
# 162804     5     AM Rahane  RA Tripathi    UT Yadav              0  ...
#
# ...

# %%
ball_df.shape
# Out:
# (179078, 21)

# %% [markdown]
# # Boxplot Method to spot the Outliers

# %%
sns.histplot(x='ball', data=ball_df,kde=False)
# Out:
# <AxesSubplot:xlabel='ball', ylabel='Count'>

# %%
sns.histplot(x='ball', data=smoke_df,kde=True)
# Out:
# <AxesSubplot:xlabel='ball', ylabel='Count'>

# %%
cols = 3
rows = 50
num_cols = ball_df.select_dtypes(exclude='object').columns
fig = plt.figure( figsize=(cols*5, rows*5))
for i, col in enumerate(num_cols):
#for i in num_cols:    
    ax=fig.add_subplot(rows,cols,i+1)
    
    sns.histplot(x = ball_df[col], ax = ax)
    
fig.tight_layout()  
plt.show()

# %%
# 2. KDE PLOT - Kernal Density Plot - sns.kdeplot()
sns.kdeplot(x='ball', data=ball_df, hue=True)
# Out:
# <AxesSubplot:xlabel='ball', ylabel='Density'>

# %%
ball_df.corr()
# Out:
#                match_id    inning      over      ball  is_super_over  \
# match_id       1.000000  0.003958  0.008268 -0.001349      -0.009150
# inning         0.003958  1.000000 -0.050076 -0.003943       0.084154
# over           0.008268 -0.050076  1.000000 -0.007424      -0.034329
# ball          -0.001349 -0.003943 -0.007424  1.000000      -0.001143
# is_super_over -0.009150  0.084154 -0.034329 -0.001143       1.000000
# wide_runs     -0.007549  0.001201 -0.010003 -0.004665      -0.001019
# bye_runs       0.000905 -0.000757  0.012111  0.006602       0.001353
# legbye_runs   -0.012429 -0.001996 -0.004764 -0.002727       0.001735
# noball_runs   -0.004623 -0.000904  0.016984  0.000567       0.013640
# penalty_runs  -0.001475  0.003442 -0.000979  0.000711      -0.000071
# batsman_runs   0.033510 -0.005362  0.086701  0.007950       0.010125
# extra_runs    -0.013323 -0.000531 -0.002479 -0.002576       0.003504
# total_runs     0.030727 -0.005485  0.086326  0.007414       0.010891
#
# ...

# %%
ball_df.corr()['noball_runs'].sort_values()
# Out:
# wide_runs       -0.008675
# legbye_runs     -0.006434
# match_id        -0.004623
# bye_runs        -0.002515
# inning          -0.000904
# penalty_runs    -0.000198
# ball             0.000567
# batsman_runs     0.004832
# is_super_over    0.013640
# over             0.016984
# total_runs       0.046427
# extra_runs       0.194899
# noball_runs      1.000000
# Name: noball_runs, dtype: float64

# %%
sns.histplot(x='ball', data=ball_df)
# Out:
# <AxesSubplot:xlabel='ball', ylabel='Count'>

# %%
#Printing the removed outliers on a boxplot

sns.boxplot(ball_df['total_runs'])
# Out:
# /Users/akanshchoudhary/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_runs'>

# %%
#Importing Matplot library in order to visualise the data in barplot

import matplotlib.pyplot as plt

cols = 5
rows = 5
num_cols = ball_df.select_dtypes(exclude='object').columns
fig = plt.figure( figsize=(cols*5, rows*5))
for i, col in enumerate(num_cols):
#for i in num_cols:    
    ax=fig.add_subplot(rows,cols,i+1)
    
    sns.histplot(x = df[col], ax = ax)
    
fig.tight_layout()  
plt.show()

# %%
sns.kdeplot(x='match_id',data=ball_df, hue='inning')
# Out:
# <AxesSubplot:xlabel='match_id', ylabel='Density'>

# %%
#Displaying Histplot and kde plot together

sns.histplot(x='match_id',data=df,kde=True)
# Out:
# <AxesSubplot:xlabel='match_id', ylabel='Count'>

# %%
sns.rugplot(x='match_id',data=ball_df, height=.03,color='skyblue')
# Out:
# <AxesSubplot:xlabel='match_id'>

# %%
#total_runs

sns.rugplot(x='total_runs',data=ball_df, height=.03,color='black')
sns.histplot(x='total_runs',data=ball_df,kde=True)
# Out:
# <AxesSubplot:xlabel='total_runs', ylabel='Count'>

# %%
sns.boxplot(x=ball_df['total_runs'])
# Out:
# <AxesSubplot:xlabel='total_runs'>

# %%
sns.boxplot(data=ball_df.loc[:,['match_id','total_runs']])
# Out:
# <AxesSubplot:>

# %%
cols = 5
rows = 5
num_cols = ball_df.select_dtypes(exclude='object').columns
fig = plt.figure(figsize= (15,9))
for i, col in enumerate(num_cols):
    
    ax=fig.add_subplot( rows, cols, i+1)
    
    sns.boxplot(x=df[col], ax=ax)
    
fig.tight_layout()  
plt.show()

# %%
sns.violinplot(x=df['total_runs'])
# Out:
# <AxesSubplot:xlabel='total_runs'>

# %%
sns.stripplot(x=ball_df["total_runs"])
# Out:
# <AxesSubplot:xlabel='total_runs'>

# %%
sns.stripplot(x=ball_df['total_runs'])
# Out:
# <AxesSubplot:xlabel='total_runs'>

# %%
ball_df.where(ball_df['total_runs']>60000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/s6/4rv1llv520q4bgmy_wzdr4s40000gn/T/ipykernel_13493/3670280787.py in <module>
# ----> 1 ball_df.where(ball_df['total_runs']>60000)
#
# NameError: name 'ball_df' is not defined

# %%
df.describe(include='object')
# Out:
#           batting_team    bowling_team  batsman non_striker           bowler  \
# count           179078          179078   179078      179078           179078
# unique              15              15      516         511              405
# top     Mumbai Indians  Mumbai Indians  V Kohli    SK Raina  Harbhajan Singh
# freq             22619           22517     4211        4173             3451
#
#        player_dismissed dismissal_kind   fielder
# count              8834           8834      6448
# unique              487              9       499
# top            SK Raina         caught  MS Dhoni
# freq                162           5348       159

# %%
import matplotlib.pyplot as plt
cols = 3
rows = 1
fig = plt.figure(figsize= (10,6))
all_categs = df.select_dtypes(include='object')
cat_cols = all_categs.columns[all_categs.nunique() < 10]
for i, col in enumerate(cat_cols):
    ax=fig.add_subplot(rows, cols, i+1)
    sns.countplot(x=df[col], ax=ax)
    plt.xticks(rotation=0, ha='right')
    
fig.tight_layout()  
plt.show()

# %%
data= df['total_runs'].value_counts()
plt.pie(data, labels=data.index, autopct= "%.0f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe7da1c76a0>,
# ...
#  [Text(0.3136104535892402, 1.0543474206349401, '1'),
#   Text(-0.9507344537478293, -0.5532666612555078, '0'),
#   Text(0.45140726655034397, -1.0031109010002568, '4'),
#   Text(0.9341297642948795, -0.5808627922826467, '2'),
#   Text(1.081609259679892, -0.20030329346946854, '6'),
#   Text(1.0995656119594637, -0.030910596827149812, '3'),
#   Text(1.0999440345990954, -0.011095978995293273, '5'),
#   Text(1.0999949919720111, -0.0033192825272074155, '8'),
#   Text(1.0999991704297523, -0.0013509455418541216, '7'),
#   Text(1.099999956632509, -0.0003088826289992982, '10')],
#  [Text(0.17106024741231285, 0.5750985930736036, '41%'),
#   Text(-0.5185824293169977, -0.301781815230277, '35%'),
#   Text(0.2462221453910967, -0.5471514005455945, '12%'),
#   Text(0.5095253259790251, -0.3168342503359891, '7%'),
#   Text(0.5899686870981229, -0.10925634189243737, '5%'),
#   Text(0.5997630610687983, -0.016860325542081715, '0%'),
# ...

# %%
#Univariate unordered categorical

df.dtypes
# Out:
# match_id             int64
# inning               int64
# batting_team        object
# bowling_team        object
# over                 int64
# ball                 int64
# batsman             object
# non_striker         object
# bowler              object
# is_super_over        int64
# wide_runs            int64
# bye_runs             int64
# legbye_runs          int64
# noball_runs          int64
# penalty_runs         int64
# batsman_runs         int64
# extra_runs           int64
# total_runs           int64
# player_dismissed    object
# dismissal_kind      object
# fielder             object
# dtype: object

# %%
#Selecting any column of datatype ='object'

df.batting_team.value_counts()
# Out:
# Mumbai Indians                 22619
# Kings XI Punjab                20931
# Royal Challengers Bangalore    20908
# Kolkata Knight Riders          20858
# Chennai Super Kings            19762
# Delhi Daredevils               18786
# Rajasthan Royals               17292
# Sunrisers Hyderabad            12908
# Deccan Chargers                 9034
# Pune Warriors                   5443
# Gujarat Lions                   3566
# Delhi Capitals                  1909
# Rising Pune Supergiant          1900
# Kochi Tuskers Kerala            1582
# Rising Pune Supergiants         1580
# Name: batting_team, dtype: int64

# %%
#Plotting barplot for the object datatype column

df.batting_team.value_counts().plot.barh()
plt.show()

# %%
#Normalising the values in order to change the values of numeric columns in the dataset to a common scale

df.batting_team.value_counts(normalize =True)
# Out:
# Mumbai Indians                 0.126308
# Kings XI Punjab                0.116882
# Royal Challengers Bangalore    0.116754
# Kolkata Knight Riders          0.116474
# Chennai Super Kings            0.110354
# Delhi Daredevils               0.104904
# Rajasthan Royals               0.096561
# Sunrisers Hyderabad            0.072080
# Deccan Chargers                0.050447
# Pune Warriors                  0.030395
# Gujarat Lions                  0.019913
# Delhi Capitals                 0.010660
# Rising Pune Supergiant         0.010610
# Kochi Tuskers Kerala           0.008834
# Rising Pune Supergiants        0.008823
# Name: batting_team, dtype: float64

# %%
#Plotting the barplot for the normalised columns

df.batting_team.value_counts(normalize =True).plot.barh()
plt.show()

# %%
#Same performed on another column

df.batting_team.value_counts()
# Out:
# Mumbai Indians                 22619
# Kings XI Punjab                20931
# Royal Challengers Bangalore    20908
# Kolkata Knight Riders          20858
# Chennai Super Kings            19762
# Delhi Daredevils               18786
# Rajasthan Royals               17292
# Sunrisers Hyderabad            12908
# Deccan Chargers                 9034
# Pune Warriors                   5443
# Gujarat Lions                   3566
# Delhi Capitals                  1909
# Rising Pune Supergiant          1900
# Kochi Tuskers Kerala            1582
# Rising Pune Supergiants         1580
# Name: batting_team, dtype: int64

# %%
df.batting_team.value_counts().plot.bar()
plt.show()

# %%
df.batting_team.value_counts(normalize=True)
# Out:
# Mumbai Indians                 0.126308
# Kings XI Punjab                0.116882
# Royal Challengers Bangalore    0.116754
# Kolkata Knight Riders          0.116474
# Chennai Super Kings            0.110354
# Delhi Daredevils               0.104904
# Rajasthan Royals               0.096561
# Sunrisers Hyderabad            0.072080
# Deccan Chargers                0.050447
# Pune Warriors                  0.030395
# Gujarat Lions                  0.019913
# Delhi Capitals                 0.010660
# Rising Pune Supergiant         0.010610
# Kochi Tuskers Kerala           0.008834
# Rising Pune Supergiants        0.008823
# Name: batting_team, dtype: float64

# %%
df.batting_team.value_counts(normalize=True).plot.bar()
plt.show()

# %%
df.total_runs.value_counts()
# Out:
# 1     73059
# 0     63002
# 4     20599
# 2     13125
# 6      8148
# 3       688
# 5       339
# 8        64
# 7        38
# 10       16
# Name: total_runs, dtype: int64

# %%
df.total_runs.value_counts().plot.pie()
plt.show()

# %%
df.total_runs.value_counts(normalize= True)
# Out:
# 1     0.407973
# 0     0.351813
# 4     0.115028
# 2     0.073292
# 6     0.045500
# 3     0.003842
# 5     0.001893
# 8     0.000357
# 7     0.000212
# 10    0.000089
# Name: total_runs, dtype: float64

# %%
df.total_runs.value_counts(normalize= True).plot.pie()
plt.show()

# %%
df.total_runs.value_counts(normalize=True).plot.bar()
plt.show()

# %%
df[~(df.total_runs== "> 6")].total_runs.value_counts(normalize=True).plot.bar()
plt.show()

# %%
df[~(df.total_runs== "100")].total_runs.value_counts(normalize=True).plot.pie()
plt.show()
